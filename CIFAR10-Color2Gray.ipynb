# %% [markdown]
# Requirements

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, Flatten, BatchNormalization, MaxPooling2D, UpSampling2D
from keras.datasets import cifar10
from keras.utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler
from keras.optimizers import Adam, SGD, RMSprop
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Problem

# %%
import cv2
from keras.datasets import cifar10
from keras.utils import to_categorical

# Load the CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

datagen = ImageDataGenerator(rotation_range=20,
                             width_shift_range=0.2,
                             height_shift_range=0.2,
                             shear_range=0.2,
                             zoom_range=0.2)

aug = datagen.flow(train_images, train_labels, batch_size=train_images.shape[0])
train_images = np.concatenate((train_images, aug[0][0]), axis=0)
train_labels = np.concatenate((train_labels, aug[0][1]), axis=0)

# Normalize the pixel values to the range [0, 1]
train_images = train_images.astype('float32')/255.0
test_images = test_images.astype('float32')/255.0

# Convert RGB images to grayscale using OpenCV
train_images_gray = []
for img in train_images:
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    train_images_gray.append(gray)

test_images_gray = []
for img in test_images:
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    test_images_gray.append(gray)

train_images_gray = np.array(train_images_gray)
test_images_gray = np.array(test_images_gray)


# Convert the labels to one-hot encoding
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
fig, axs = plt.subplots(1, 2, figsize=(10,10))
axs[0].imshow(train_images[4], cmap='gray')
axs[1].imshow(train_images_gray[4], cmap='gray')
plt.show()

# %%
# Define the autoencoder model
model = Sequential()

# Encoder layers
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 1)))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2), padding='same'))

model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2), padding='same'))

model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2), padding='same'))

model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2), padding='same'))

# Decoder layers
model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(3, (3, 3), activation='sigmoid', padding='same'))

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_181 (Conv2D)         (None, 32, 32, 32)        320
#
#  conv2d_182 (Conv2D)         (None, 32, 32, 32)        9248
#
#  max_pooling2d_60 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  conv2d_183 (Conv2D)         (None, 16, 16, 64)        18496
#
#  conv2d_184 (Conv2D)         (None, 16, 16, 64)        36928
#
#  max_pooling2d_61 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  conv2d_185 (Conv2D)         (None, 8, 8, 128)         73856
#
#  conv2d_186 (Conv2D)         (None, 8, 8, 128)         147584
#
#  max_pooling2d_62 (MaxPoolin  (None, 4, 4, 128)        0
#  g2D)
#
#  conv2d_187 (Conv2D)         (None, 4, 4, 256)         295168
#
#  conv2d_188 (Conv2D)         (None, 4, 4, 256)         590080
#
#  max_pooling2d_63 (MaxPoolin  (None, 2, 2, 256)        0
#  g2D)
#
#  conv2d_189 (Conv2D)         (None, 2, 2, 256)         590080
#
#  up_sampling2d_61 (UpSamplin  (None, 4, 4, 256)        0
#  g2D)
#
#  conv2d_190 (Conv2D)         (None, 4, 4, 128)         295040
#
#  conv2d_191 (Conv2D)         (None, 4, 4, 128)         147584
#
#  up_sampling2d_62 (UpSamplin  (None, 8, 8, 128)        0
#  g2D)
#
#  conv2d_192 (Conv2D)         (None, 8, 8, 64)          73792
#
#  conv2d_193 (Conv2D)         (None, 8, 8, 64)          36928
#
#  up_sampling2d_63 (UpSamplin  (None, 16, 16, 64)       0
#  g2D)
#
#  conv2d_194 (Conv2D)         (None, 16, 16, 32)        18464
#
#  conv2d_195 (Conv2D)         (None, 16, 16, 32)        9248
#
#  up_sampling2d_64 (UpSamplin  (None, 32, 32, 32)       0
#  g2D)
#
#  conv2d_196 (Conv2D)         (None, 32, 32, 3)         867
#
# =================================================================
# Total params: 2,343,683
# Trainable params: 2,343,683
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(train_images_gray, train_images, epochs=30, batch_size=32, validation_data=(test_images_gray, test_images), verbose=2)
# Out:
# Epoch 1/30
# 3125/3125 - 29s - loss: 0.0215 - val_loss: 0.0175 - 29s/epoch - 9ms/step
# Epoch 2/30
# 3125/3125 - 26s - loss: 0.0148 - val_loss: 0.0153 - 26s/epoch - 8ms/step
# Epoch 3/30
# 3125/3125 - 25s - loss: 0.0132 - val_loss: 0.0138 - 25s/epoch - 8ms/step
# Epoch 4/30
# 3125/3125 - 25s - loss: 0.0123 - val_loss: 0.0132 - 25s/epoch - 8ms/step
# Epoch 5/30
# 3125/3125 - 25s - loss: 0.0116 - val_loss: 0.0125 - 25s/epoch - 8ms/step
# Epoch 6/30
# 3125/3125 - 25s - loss: 0.0110 - val_loss: 0.0119 - 25s/epoch - 8ms/step
# Epoch 7/30
# 3125/3125 - 25s - loss: 0.0106 - val_loss: 0.0115 - 25s/epoch - 8ms/step
# Epoch 8/30
# 3125/3125 - 25s - loss: 0.0102 - val_loss: 0.0112 - 25s/epoch - 8ms/step
# Epoch 9/30
# 3125/3125 - 25s - loss: 0.0098 - val_loss: 0.0107 - 25s/epoch - 8ms/step
# Epoch 10/30
# 3125/3125 - 25s - loss: 0.0095 - val_loss: 0.0105 - 25s/epoch - 8ms/step
# Epoch 11/30
# 3125/3125 - 25s - loss: 0.0093 - val_loss: 0.0101 - 25s/epoch - 8ms/step
# Epoch 12/30
# 3125/3125 - 25s - loss: 0.0091 - val_loss: 0.0099 - 25s/epoch - 8ms/step
# Epoch 13/30
# 3125/3125 - 25s - loss: 0.0089 - val_loss: 0.0098 - 25s/epoch - 8ms/step
# Epoch 14/30
# 3125/3125 - 25s - loss: 0.0087 - val_loss: 0.0098 - 25s/epoch - 8ms/step
# Epoch 15/30
# 3125/3125 - 25s - loss: 0.0086 - val_loss: 0.0094 - 25s/epoch - 8ms/step
# Epoch 16/30
# 3125/3125 - 25s - loss: 0.0084 - val_loss: 0.0094 - 25s/epoch - 8ms/step
# Epoch 17/30
# 3125/3125 - 25s - loss: 0.0083 - val_loss: 0.0092 - 25s/epoch - 8ms/step
# Epoch 18/30
# 3125/3125 - 25s - loss: 0.0081 - val_loss: 0.0091 - 25s/epoch - 8ms/step
# Epoch 19/30
# 3125/3125 - 25s - loss: 0.0080 - val_loss: 0.0091 - 25s/epoch - 8ms/step
# Epoch 20/30
# 3125/3125 - 25s - loss: 0.0078 - val_loss: 0.0090 - 25s/epoch - 8ms/step
# Epoch 21/30
# 3125/3125 - 25s - loss: 0.0077 - val_loss: 0.0088 - 25s/epoch - 8ms/step
# Epoch 22/30
# 3125/3125 - 25s - loss: 0.0076 - val_loss: 0.0091 - 25s/epoch - 8ms/step
# Epoch 23/30
# 3125/3125 - 25s - loss: 0.0075 - val_loss: 0.0089 - 25s/epoch - 8ms/step
# Epoch 24/30
# 3125/3125 - 25s - loss: 0.0074 - val_loss: 0.0087 - 25s/epoch - 8ms/step
# Epoch 25/30
# 3125/3125 - 25s - loss: 0.0073 - val_loss: 0.0089 - 25s/epoch - 8ms/step
# Epoch 26/30
# 3125/3125 - 25s - loss: 0.0072 - val_loss: 0.0087 - 25s/epoch - 8ms/step
# Epoch 27/30
# 3125/3125 - 25s - loss: 0.0071 - val_loss: 0.0086 - 25s/epoch - 8ms/step
# Epoch 28/30
# 3125/3125 - 25s - loss: 0.0070 - val_loss: 0.0088 - 25s/epoch - 8ms/step
# Epoch 29/30
# 3125/3125 - 25s - loss: 0.0069 - val_loss: 0.0086 - 25s/epoch - 8ms/step
# Epoch 30/30
# 3125/3125 - 25s - loss: 0.0068 - val_loss: 0.0087 - 25s/epoch - 8ms/step

# %%
# Plot Some Color Images from Dataset And Prediction From Model
n = 5
imgs = test_images[:n]

imgs_gray = []
for img in imgs:
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    imgs_gray.append(gray)

imgs_gray = np.array(imgs_gray)
imgs_gray = imgs_gray.reshape(-1, 32, 32, 1)

decoded_imgs = model.predict(imgs_gray)

fig, axes = plt.subplots(nrows=2, ncols=n, figsize=(20, 4))

for i in range(n):
    axes[0,i].imshow(imgs[i])
    axes[0,i].get_xaxis().set_visible(False)
    axes[0,i].get_yaxis().set_visible(False)

    axes[1,i].imshow(decoded_imgs[i])
    axes[1,i].get_xaxis().set_visible(False)
    axes[1,i].get_yaxis().set_visible(False)

plt.show()
# Out:
# WARNING:tensorflow:5 out of the last 27 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7c98712d55a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 175ms/step

# %%
# Load desire image
image = cv2.imread('car.jpg')
image = cv2.resize(image,(32, 32))
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

# Preprocess on input image
gray_image = cv2.resize(gray_image,(32, 32))
img = gray_image.reshape(1, 32, 32, 1)
img = img.astype('float32')/255.

# Prediction
prediction_img = model.predict(img)
prediction_img = prediction_img.reshape(32, 32, 3)

fig, axs = plt.subplots(1, 2, figsize=(10,10))
axs[0].imshow(image, cmap='gray')
axs[0].set_title('Uploaded Image')
axs[1].imshow(prediction_img, cmap='gray')
axs[1].set_title('Colorized Image by Model')
plt.show()
# Out:
# 1/1 [==============================] - 0s 42ms/step
